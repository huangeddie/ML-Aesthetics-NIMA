# %%
import models.neural_network
# Out:
# Using TensorFlow backend.

# %%
models_to_train = [
    models.neural_network.NeuralNetwork,
]

# %%
# %%time
for Model in models_to_train:
    model = Model()
    model.load()
    model.train()
    version = model.checkpoint()
    print('Saved {} to version {}'.format(Model.__name__, version))
# Out:
# Epoch 1/10
# 3976/3976 [==============================] - 13s 3ms/step - loss: 120399299.0455 - mean_squared_error: 120399299.0455
# Epoch 2/10
# 3976/3976 [==============================] - 10s 2ms/step - loss: 99.1659 - mean_squared_error: 99.1659
# Epoch 3/10
# 3976/3976 [==============================] - 10s 2ms/step - loss: 0.9996 - mean_squared_error: 0.9996
# Epoch 4/10
# 3976/3976 [==============================] - 10s 2ms/step - loss: 0.9995 - mean_squared_error: 0.9995
# Epoch 5/10
# 3976/3976 [==============================] - 10s 2ms/step - loss: 0.9993 - mean_squared_error: 0.9993
# Epoch 6/10
# 3976/3976 [==============================] - 10s 2ms/step - loss: 0.9991 - mean_squared_error: 0.9991
# Epoch 7/10
# 3976/3976 [==============================] - 10s 2ms/step - loss: 0.9989 - mean_squared_error: 0.9989
# Epoch 8/10
# 3976/3976 [==============================] - 10s 2ms/step - loss: 0.9987 - mean_squared_error: 0.9987
# Epoch 9/10
# 3976/3976 [==============================] - 9s 2ms/step - loss: 0.9985 - mean_squared_error: 0.9985
# Epoch 10/10
# 3976/3976 [==============================] - 9s 2ms/step - loss: 0.9983 - mean_squared_error: 0.9983
# Saved NeuralNetwork to version 1
# CPU times: user 1min 30s, sys: 23.8 s, total: 1min 54s
# Wall time: 1min 56s

# %%
# %%time
for Model in models_to_train:
    model = Model()
    model.load()
    version = model.checkpoint()
    print('Saved {} to version {}'.format(Model.__name__, version))
# Out:
# Saved NeuralNetwork to version 2
# CPU times: user 5.32 s, sys: 3.21 s, total: 8.52 s
# Wall time: 8.3 s
