# %%
import models.densenet
# Out:
# Using TensorFlow backend.

# %%
models_to_train = [
    models.densenet.DenseNet,
]

# %%
# %%time
for Model in models_to_train:
    model = Model()
    model.load()
    model.train()
    version = model.checkpoint()
    print('Saved {} to version {}'.format(Model.__name__, version))
# Out:
# Epoch 1/1
# 3976/3976 [==============================] - 170s 43ms/step - loss: 1.0369 - mean_squared_error: 1.0369
# Saved DenseNet to version 2
# CPU times: user 9min 32s, sys: 40.3 s, total: 10min 13s
# Wall time: 9min 53s
